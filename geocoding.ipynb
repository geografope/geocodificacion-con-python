# %% [markdown]
# <a href="https://colab.research.google.com/github/ambarja/geocodificacion-con-python/blob/main/geocoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://raw.githubusercontent.com/geografope/geocodificacion-con-python/main/img/banner.png'>

# %% [markdown]
# Este tutorial fue elaboradro por **Geografo.PE**
#
# Redes sociales:
# - Youtube: www.youtube.com/@ambarja
# - Tiktok: https://www.tiktok.com/@geografo.pe
# - Linkdin: https://www.linkedin.com/in/antonybarja/
# - GitHub: https://github.com/geografope
#
# Para más información, puedes visitar mi pagina personal:*https://geografo.pe*

# %% [markdown]
# ### **1.Instalación de librerias a utilizar**

# %%
# !pip install geopy
# !pip install pandas
# !pip install geopandas
# !pip install mapclassify

# %% [markdown]
# ### **2.Llamado o activación de librerias**

# %%
from geopy.geocoders import Nominatim, ArcGIS, MapBox
import pandas as pd
import geopandas as gpd
from functools import partial

# %% [markdown]
# ### **3.Lectura de los datos crudos en formato excel**

# %%
url = 'https://github.com/geografope/geocodificacion-con-python/raw/main/rawdata/rawdata.xlsx'
rawdata = pd.read_excel(url)

# %%
rawdata.shape
# Out:
# (19, 4)

# %% [markdown]
# ### **4.Función para estandarizar extructura de texto para geocodificar**

# %%
# Forma estandar de la estructura del texto para geodificar con Nominatim:
# direccion,distrito,provincia,departamento,pais
# Ejemplo: "Calle Los Angeles 123, Carabayllo, Lima, Lima, Perú"
def concatenar_campos(row):
    return f"{row['direccion']}, {row['distrito']}, {row['provincia']}, {row['departamento']}, Perú"

# %%
rawdata['nogeo'] = rawdata.apply(concatenar_campos, axis= 1)
rawdata.head()

# %%
rawdata_for_osm = rawdata.copy()
rawdata_for_mapbox = rawdata.copy()
rawdata_for_arcgis = rawdata.copy()

# %% [markdown]
# ### **5.Gecodificación directa con la API de OSM**
# - Nominatim: Es una herramienta open source que sirve para realizar proceso de geocodificación a través de OpenSteetMap.
# Referencia: *https://github.com/osm-search/Nominatim*

# %%
# Gecodificación directa
geolocator = Nominatim(user_agent="geografo_pe",timeout = 5)
geocode = partial(geolocator.geocode, language="es")
def tidygeocode(row):
    location = geolocator.geocode(row['nogeo'])
    if location:
        return pd.Series({'latitude': location.latitude, 'longitude': location.longitude})
    else:
        return pd.Series({'latitude': None, 'longitude': None})

# %%
rawdata_for_osm[['latitude', 'longitude']] = rawdata_for_osm.apply(tidygeocode, axis=1)

# %%
rawdata_for_osm
# Out:
#    departamento provincia       distrito  \
# 0          Lima      Lima    Santa Anita
# 1          Lima      Lima    Santa Anita
# 2          Lima      Lima    Santa Anita
# 3          Lima      Lima     Lurigancho
# 4          Lima      Lima     Lurigancho
# 5          Lima      Lima     Lurigancho
# 6          Lima      Lima     Lurigancho
# 7          Lima      Lima      Surquillo
# 8          Lima      Lima      Surquillo
# 9          Lima      Lima      Surquillo
# 10         Lima      Lima     Miraflores
# 11         Lima      Lima     Miraflores
# 12         Lima      Lima     Miraflores
# 13         Lima      Lima     Miraflores
# 14         Lima      Lima  Puente Piedra
# 15         Lima      Lima  Puente Piedra
# 16         Lima      Lima  Puente Piedra
# 17         Lima      Lima  Puente Piedra
# 18         Lima      Lima  Puente Piedra
#
#                                             direccion  \
# 0            Carretera Central 167, Santa Anita 15008
# 1           Jiron los Eucaliptos 996, La Molina 15023
# 2         Avenida Metropolitana Mz M Lot 4, Ate 15026
# 3                              Los Robles, Lima 15457
# 4             Avenida las Torres 276, Lima, Ate 15498
# 5              Avenida Nicolás Ayllón 7208, Ate 15487
# 6           La Capitana 190, Lurigancho-Chosica 15461
# 7     Avenida Angamos Este 1807-1803, Surquillo 15036
# 8   Avenida República de Panamá 4295, Surquillo 15048
# 9                     Gonzáles Prada, Surquillo 15047
# 10             Calle Bellavista 207, Miraflores 15074
# 11                 Avenida Grau 299, Miraflores 15074
# 12                 Alfredo Leon 114, Miraflores 15074
# 13                Calle Berlín 1273, Miraflores 15074
# 14              Pasaje Las Vegas, Puente Piedra 15118
# 15          Calle 9 de Junio 100, Puente Piedra 15115
# 16  Avenida sanez numero 300 urbaizacion cercado d...
# 17                 Calle 8 6-130, Puente Piedra 15117
# 18               Calle 8 132-356, Puente Piedra 15117
#
#                                                 nogeo   latitude  longitude
# 0   Carretera Central 167, Santa Anita 15008, Sant... -12.045751 -76.942885
# 1   Jiron los Eucaliptos 996, La Molina 15023, San...        NaN        NaN
# 2   Avenida Metropolitana Mz M Lot 4, Ate 15026, S...        NaN        NaN
# 3   Los Robles, Lima 15457, Lurigancho, Lima, Lima... -12.010709 -76.909938
# 4   Avenida las Torres 276, Lima, Ate 15498, Lurig... -12.014345 -76.900770
# 5   Avenida Nicolás Ayllón 7208, Ate 15487, Luriga...        NaN        NaN
# 6   La Capitana 190, Lurigancho-Chosica 15461, Lur...        NaN        NaN
# 7   Avenida Angamos Este 1807-1803, Surquillo 1503...        NaN        NaN
# 8   Avenida República de Panamá 4295, Surquillo 15... -12.116153 -77.018354
# 9   Gonzáles Prada, Surquillo 15047, Surquillo, Li... -12.116403 -77.021011
# 10  Calle Bellavista 207, Miraflores 15074, Mirafl... -12.122818 -77.032740
# 11  Avenida Grau 299, Miraflores 15074, Miraflores... -12.120170 -77.034772
# 12  Alfredo Leon 114, Miraflores 15074, Miraflores... -12.121135 -77.037995
# 13  Calle Berlín 1273, Miraflores 15074, Miraflore... -12.120104 -77.040088
# 14  Pasaje Las Vegas, Puente Piedra 15118, Puente ...        NaN        NaN
# 15  Calle 9 de Junio 100, Puente Piedra 15115, Pue...        NaN        NaN
# 16  Avenida sanez numero 300 urbaizacion cercado d...        NaN        NaN
# 17  Calle 8 6-130, Puente Piedra 15117, Puente Pie... -11.884888 -77.070530
# 18  Calle 8 132-356, Puente Piedra 15117, Puente P...        NaN        NaN

# %% [markdown]
# ### **6.Visualización de datos espaciales**

# %%
# Eliminar datos vacios
geo_rawdata = rawdata_for_osm.dropna()
# Dataframe a gepandas
geo_rawdata = gpd.GeoDataFrame(data = geo_rawdata, geometry=gpd.points_from_xy(geo_rawdata.longitude, geo_rawdata.latitude),crs = 4326)

# %%
# Visualización interactiva
geo_rawdata.explore(tiles = "Esri.WorldImagery",marker_kwds={'radius': 10} )

# %% [markdown]
# ### **7.Geocodificación inversa**

# %%
# Geocodificación indirecta
def tidygeocode_inv(row):
  adress = geolocator.reverse([row['latitude'],row['longitude']])
  return(str(adress))

# %%
geocode_inv = geo_rawdata.copy()

# %%
geocode_inv['direccion_geo_inv'] = geocode_inv.apply(tidygeocode_inv, axis = 1)

# %%
geocode_inv = geocode_inv.drop(columns=['geometry'])
geocode_inv = gpd.GeoDataFrame(data = geocode_inv, geometry=gpd.points_from_xy(geo_rawdata.longitude, geo_rawdata.latitude),crs = 4326)

# %%
geocode_inv

# %% [markdown]
# ### **8.Exportar datos espaciales**

# %%
# Exportar datos en formato gpkg
geo_rawdata.to_file('geocoding_directo.gpkg')
geocode_inv.to_file('geocoding_inverso.gpkg')

# %% [markdown]
# ### **9.Gecodificación usando la API de MapBox**
# Para poder optener nuestra API de MapBox tenemos que registrarnos en el siguiente enlace:
#  - Registro: *https://account.mapbox.com/auth/signup/*
#  - Activar API: *https://account.mapbox.com/access-tokens/create*
#
# #### *Geocodificación gratis: 100 000 al mes*

# %%
api_mapbox = 'PON_TU_API_KEY_AQUI'
geolocator = MapBox(api_key = api_mapbox)
def tidygeocode(row):
    location = geolocator.geocode(row['nogeo'])
    if location:
        return pd.Series({'latitude': location.latitude, 'longitude': location.longitude})
    else:
        return pd.Series({'latitude': None, 'longitude': None})

# %%
rawdata_for_mapbox[['latitude', 'longitude']] = rawdata_for_mapbox.apply(tidygeocode, axis=1)

# %%
rawdata_for_mapbox
# Out:
#    departamento provincia       distrito  \
# 0          Lima      Lima    Santa Anita
# 1          Lima      Lima    Santa Anita
# 2          Lima      Lima    Santa Anita
# 3          Lima      Lima     Lurigancho
# 4          Lima      Lima     Lurigancho
# 5          Lima      Lima     Lurigancho
# 6          Lima      Lima     Lurigancho
# 7          Lima      Lima      Surquillo
# 8          Lima      Lima      Surquillo
# 9          Lima      Lima      Surquillo
# 10         Lima      Lima     Miraflores
# 11         Lima      Lima     Miraflores
# 12         Lima      Lima     Miraflores
# 13         Lima      Lima     Miraflores
# 14         Lima      Lima  Puente Piedra
# 15         Lima      Lima  Puente Piedra
# 16         Lima      Lima  Puente Piedra
# 17         Lima      Lima  Puente Piedra
# 18         Lima      Lima  Puente Piedra
#
#                                             direccion  \
# 0            Carretera Central 167, Santa Anita 15008
# 1           Jiron los Eucaliptos 996, La Molina 15023
# 2         Avenida Metropolitana Mz M Lot 4, Ate 15026
# 3                              Los Robles, Lima 15457
# 4             Avenida las Torres 276, Lima, Ate 15498
# 5              Avenida Nicolás Ayllón 7208, Ate 15487
# 6           La Capitana 190, Lurigancho-Chosica 15461
# 7     Avenida Angamos Este 1807-1803, Surquillo 15036
# 8   Avenida República de Panamá 4295, Surquillo 15048
# 9                     Gonzáles Prada, Surquillo 15047
# 10             Calle Bellavista 207, Miraflores 15074
# 11                 Avenida Grau 299, Miraflores 15074
# 12                 Alfredo Leon 114, Miraflores 15074
# 13                Calle Berlín 1273, Miraflores 15074
# 14              Pasaje Las Vegas, Puente Piedra 15118
# 15          Calle 9 de Junio 100, Puente Piedra 15115
# 16  Avenida sanez numero 300 urbaizacion cercado d...
# 17                 Calle 8 6-130, Puente Piedra 15117
# 18               Calle 8 132-356, Puente Piedra 15117
#
#                                                 nogeo   latitude  longitude
# 0   Carretera Central 167, Santa Anita 15008, Sant... -12.048364 -76.971911
# 1   Jiron los Eucaliptos 996, La Molina 15023, San... -12.089682 -76.957556
# 2   Avenida Metropolitana Mz M Lot 4, Ate 15026, S... -12.042531 -76.962451
# 3   Los Robles, Lima 15457, Lurigancho, Lima, Lima... -12.010709 -76.909938
# 4   Avenida las Torres 276, Lima, Ate 15498, Lurig... -12.001441 -76.921296
# 5   Avenida Nicolás Ayllón 7208, Ate 15487, Luriga... -11.957943 -76.728594
# 6   La Capitana 190, Lurigancho-Chosica 15461, Lur... -11.972625 -76.931578
# 7   Avenida Angamos Este 1807-1803, Surquillo 1503... -12.109998 -76.979985
# 8   Avenida República de Panamá 4295, Surquillo 15... -12.110501 -77.018335
# 9   Gonzáles Prada, Surquillo 15047, Surquillo, Li... -12.116907 -77.019599
# 10  Calle Bellavista 207, Miraflores 15074, Mirafl... -12.120831 -77.031994
# 11  Avenida Grau 299, Miraflores 15074, Miraflores... -12.121223 -77.034818
# 12  Alfredo Leon 114, Miraflores 15074, Miraflores... -12.119349 -77.039751
# 13  Calle Berlín 1273, Miraflores 15074, Miraflore... -12.120072 -77.042339
# 14  Pasaje Las Vegas, Puente Piedra 15118, Puente ... -11.873307 -77.057781
# 15  Calle 9 de Junio 100, Puente Piedra 15115, Pue... -11.876333 -77.074534
# 16  Avenida sanez numero 300 urbaizacion cercado d... -11.876333 -77.074534
# 17  Calle 8 6-130, Puente Piedra 15117, Puente Pie... -11.950650 -76.993833
# 18  Calle 8 132-356, Puente Piedra 15117, Puente P... -11.950650 -76.993833

# %% [markdown]
# ### **10.Gecodificación usando la API de ArcGIS**
# Para poder optener nuestra API de ArcGIS tenemos que registrarnos en el siguiente enlace:
#  * Registro: *https://developers.arcgis.com/sign-up/*
#  * Activar API: *https://developers.arcgis.com/dashboard/#*
#
# #### *Geocodificación gratis: 20 000 gratis*

# %%
api_arcgis = 'PON_TU_API_KEY_AQUI'
geolocator = ArcGIS(auth_domain = api_arcgis)
def tidygeocode(row):
    location = geolocator.geocode(row['nogeo'])
    if location:
        return pd.Series({'latitude': location.latitude, 'longitude': location.longitude})
    else:
        return pd.Series({'latitude': None, 'longitude': None})

# %%
rawdata_for_arcgis[['latitude', 'longitude']] = rawdata_for_arcgis.apply(tidygeocode, axis=1)

# %%
rawdata_for_arcgis
# Out:
#    departamento provincia       distrito  \
# 0          Lima      Lima    Santa Anita
# 1          Lima      Lima    Santa Anita
# 2          Lima      Lima    Santa Anita
# 3          Lima      Lima     Lurigancho
# 4          Lima      Lima     Lurigancho
# 5          Lima      Lima     Lurigancho
# 6          Lima      Lima     Lurigancho
# 7          Lima      Lima      Surquillo
# 8          Lima      Lima      Surquillo
# 9          Lima      Lima      Surquillo
# 10         Lima      Lima     Miraflores
# 11         Lima      Lima     Miraflores
# 12         Lima      Lima     Miraflores
# 13         Lima      Lima     Miraflores
# 14         Lima      Lima  Puente Piedra
# 15         Lima      Lima  Puente Piedra
# 16         Lima      Lima  Puente Piedra
# 17         Lima      Lima  Puente Piedra
# 18         Lima      Lima  Puente Piedra
#
#                                             direccion  \
# 0            Carretera Central 167, Santa Anita 15008
# 1           Jiron los Eucaliptos 996, La Molina 15023
# 2         Avenida Metropolitana Mz M Lot 4, Ate 15026
# 3                              Los Robles, Lima 15457
# 4             Avenida las Torres 276, Lima, Ate 15498
# 5              Avenida Nicolás Ayllón 7208, Ate 15487
# 6           La Capitana 190, Lurigancho-Chosica 15461
# 7     Avenida Angamos Este 1807-1803, Surquillo 15036
# 8   Avenida República de Panamá 4295, Surquillo 15048
# 9                     Gonzáles Prada, Surquillo 15047
# 10             Calle Bellavista 207, Miraflores 15074
# 11                 Avenida Grau 299, Miraflores 15074
# 12                 Alfredo Leon 114, Miraflores 15074
# 13                Calle Berlín 1273, Miraflores 15074
# 14              Pasaje Las Vegas, Puente Piedra 15118
# 15          Calle 9 de Junio 100, Puente Piedra 15115
# 16  Avenida sanez numero 300 urbaizacion cercado d...
# 17                 Calle 8 6-130, Puente Piedra 15117
# 18               Calle 8 132-356, Puente Piedra 15117
#
#                                                 nogeo   latitude  longitude
# 0   Carretera Central 167, Santa Anita 15008, Sant... -12.056697 -76.969772
# 1   Jiron los Eucaliptos 996, La Molina 15023, San... -12.065913 -76.967481
# 2   Avenida Metropolitana Mz M Lot 4, Ate 15026, S... -12.033272 -76.940326
# 3   Los Robles, Lima 15457, Lurigancho, Lima, Lima... -12.010731 -76.909908
# 4   Avenida las Torres 276, Lima, Ate 15498, Lurig... -12.009716 -76.905490
# 5   Avenida Nicolás Ayllón 7208, Ate 15487, Luriga... -12.015194 -76.886799
# 6   La Capitana 190, Lurigancho-Chosica 15461, Lur... -12.009340 -76.905460
# 7   Avenida Angamos Este 1807-1803, Surquillo 1503... -12.112210 -77.010670
# 8   Avenida República de Panamá 4295, Surquillo 15... -12.107650 -77.018440
# 9   Gonzáles Prada, Surquillo 15047, Surquillo, Li... -12.116500 -77.022113
# 10  Calle Bellavista 207, Miraflores 15074, Mirafl... -12.120800 -77.031960
# 11  Avenida Grau 299, Miraflores 15074, Miraflores... -12.121150 -77.034760
# 12  Alfredo Leon 114, Miraflores 15074, Miraflores... -12.119380 -77.039810
# 13  Calle Berlín 1273, Miraflores 15074, Miraflore... -12.120110 -77.042210
# 14  Pasaje Las Vegas, Puente Piedra 15118, Puente ... -11.867809 -77.076653
# 15  Calle 9 de Junio 100, Puente Piedra 15115, Pue... -11.867419 -77.078053
# 16  Avenida sanez numero 300 urbaizacion cercado d... -11.838300 -77.098630
# 17  Calle 8 6-130, Puente Piedra 15117, Puente Pie... -11.866935 -77.073642
# 18  Calle 8 132-356, Puente Piedra 15117, Puente P... -11.866935 -77.073642
